# %%
# %matplotlib qt

import mne
import numpy as np
import matplotlib.pyplot as plt

# %%
dir_main = '../CaC_SEEG'
subj = 'P012'
task = ['chasing', 'fitting']

edf_raw = mne.io.read_raw_edf(f'{dir_main}/{subj}/{subj}_{task[0]}_{task[1]}.edf', preload=True)

# %%
edf_raw.plot(block=True, duration=5.0)
# Out:
# Channels marked as bad:
# none
# Attempting to create new mne-python configuration file:
# /home/owo/.mne/mne-python.json
# <MNEBrowseFigure size 800x800 with 4 Axes>
